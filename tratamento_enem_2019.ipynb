# %% [markdown]
# <a href="https://colab.research.google.com/github/Eduardo-Nogueira-98141225/Analise_estatistica_de_dados_enem_2019/blob/main/tratamento_enem_2019.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### PROJETO ANÁLISE ESTATISTICA  DO ENEM 2019 ###

# %%
import numpy as np
import pandas as pd

# %%
dados = pd.read_csv('/microdados_enem_2019_sp.csv' ,sep=';', encoding='iso-8859-1')

# %%
dados.head()
# Out:
#   NU_INSCRICAO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0     1,90E+11                  3546801            Santa Isabel
# 1     1,90E+11                  3538204             Pinhalzinho
# 2     1,90E+11                  3550308               São Paulo
# 3     1,90E+11                  3548708   São Bernardo do Campo
# 4     1,90E+11                  3549409    São Joaquim da Barra
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                35               SP        22       M                1
# 1                35               SP        19       M                1
# 2                35               SP        17       F                1
# 3                35               SP        19       M                1
# 4                35               SP        37       M                2
#
#    TP_COR_RACA  TP_NACIONALIDADE  ...  NU_NOTA_MT TP_LINGUA  \
# 0            3                 1  ...      6002.0       0.0
# ...
